# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Movie.csv")

# %%
df
# Out:
#                         Movie  Trending Weeks            Genre1     Genre3  \
# 0            Shyam Singha Roy             2.0  Historical Drama    Romance
# 1         The Royal Treatment             2.0           Romance        NaN
# 2    Chandigarh Kare Aashiqui             4.0           Romance        NaN
# 3                Sooryavanshi             9.0            Action        NaN
# 4               Minnal Murali             6.0            Action  Adventure
# ..                        ...             ...               ...        ...
# 992                       NaN             NaN               NaN        NaN
# 993                       NaN             NaN               NaN        NaN
# 994                       NaN             NaN               NaN        NaN
# 995                       NaN             NaN               NaN        NaN
# 996                       NaN             NaN               NaN        NaN
#
#      IMDb
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 992   NaN
# 993   NaN
# 994   NaN
# 995   NaN
# 996   NaN
#
# [997 rows x 5 columns]

# %%
df['Genre1'] = df['Genre1'].str.strip()
df['Genre3'] = df['Genre3'].str.strip()

# %%
MystoryThriller = sum(df["Genre1"]=="Thriller")+sum(df["Genre3"]=="Thriller")+sum(df["Genre1"]=="Mystery")+sum(df["Genre3"]=="Mystery")

# %%
Action= sum(df["Genre1"]=="Action")+sum(df["Genre3"]=="Action")

# %%
Comedy=sum(df["Genre1"]=="Comedy")+sum(df["Genre3"]=="Comedy")

# %%
Horror=sum(df["Genre1"]=="Horror")+sum(df["Genre3"]=="Horror")

# %%
Romance=sum(df["Genre1"]=="Romance")+sum(df["Genre3"]=="Romance")

# %%
HistoricalDrama=sum(df["Genre1"]=="Historical Drama")+sum(df["Genre3"]=="Historical Drama")

# %%
ScienceFiction=sum(df["Genre1"]=="Science Fiction")+sum(df["Genre3"]=="Science Fiction")

# %%
Fantasy=sum(df["Genre1"]=="Fantasy")+sum(df["Genre3"]=="Fantasy")

# %%
Anime=sum(df["Genre1"]=="Anime")+sum(df["Genre3"]=="Anime")

# %%
total = MystoryThriller+Action+Comedy+Horror+Romance+HistoricalDrama+ScienceFiction+Fantasy+Anime

# %%
MystoryThriller/total*100
# Out:
# 27.956989247311824

# %%
Action/total*100
# Out:
# 25.806451612903224

# %%
Comedy/total*100
# Out:
# 18.27956989247312

# %%
Horror/total*100
# Out:
# 5.376344086021505

# %%
Romance/total*100
# Out:
# 12.365591397849462

# %%
total
# Out:
# 186

# %%
HistoricalDrama/total*100
# Out:
# 1.6129032258064515

# %%
ScienceFiction/total*100
# Out:
# 2.1505376344086025

# %%
Fantasy/total*100
# Out:
# 5.376344086021505

# %%
Anime/total*100
# Out:
# 1.0752688172043012

# %%
genre = ["MystoryThriller","Action","Comedy","Horror","Romance","Fantasy","Others"]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie([MystoryThriller,Action,Comedy,Horror,Romance,Fantasy,Anime+ScienceFiction+HistoricalDrama], labels = genre,autopct='%1.2f%%')
plt.show()

# %%
df = pd.read_csv("boxcollection.csv",encoding='ISO-8859-1')

# %%
df = df[df["Box Office India"]>=50]
df = df.reset_index()
df = df.drop(columns=["index"])
df['Genre1'] = df['Genre1'].str.strip()
df['Genre3'] = df['Genre3'].str.strip()
df['movie_director'] = df['movie_director'].str.strip()
df['actor1'] = df['actor1'].str.strip()
df['actor2'] = df['actor2'].str.strip()
df['actor3'] = df['actor3'].str.strip()

# %%
df.Genre1.unique()
# Out:
# array(['Action', 'Comedy', 'Romance', 'Dance', 'Historical Drama',
#        'Sci-fi', 'Biographical', nan, 'Musical'], dtype=object)

# %%
MystoryThriller = sum(df["Genre1"]=="Thriller")+sum(df["Genre3"]=="Thriller")+sum(df["Genre1"]=="Mystery")+sum(df["Genre3"]=="Mystery")

Action= sum(df["Genre1"]=="Action")+sum(df["Genre3"]=="Action")

Comedy=sum(df["Genre1"]=="Comedy")+sum(df["Genre3"]=="Comedy")

Horror=sum(df["Genre1"]=="Horror")+sum(df["Genre3"]=="Horror")

Romance=sum(df["Genre1"]=="Romance")+sum(df["Genre3"]=="Romance")

HistoricalDrama=sum(df["Genre1"]=="Historical Drama")+sum(df["Genre3"]=="Historical Drama")

ScienceFiction=sum(df["Genre1"]=="Sci-fi")+sum(df["Genre3"]=="Sci-fi")

Biographical=sum(df["Genre1"]=="Biographical")+sum(df["Genre3"]=="Biographical")

Others=sum(df["Genre1"]=="Dance")+sum(df["Genre3"]=="Dance")+sum(df["Genre1"]=="Musical")+sum(df["Genre3"]=="Musical")

total = MystoryThriller+Action+Comedy+Horror+Romance+HistoricalDrama+ScienceFiction+Fantasy+Anime

MystoryThriller/total*100

Action/total*100

Comedy/total*100

Horror/total*100

Romance/total*100

HistoricalDrama/total*100

ScienceFiction/total*100

Biographical/total*100

Others/total*100

genre = ["MystoryThriller","Action","Comedy","Romance","HistoricalDrama","Biographical","Others"]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie([MystoryThriller,Action,Comedy,Romance,HistoricalDrama,Biographical,Others+Horror+ScienceFiction], labels = genre,autopct='%1.2f%%')
plt.show()

# %%
df
# Out:
#                           movie_name  Box Office India            Genre1  \
# 0                           Baaghi 3             93.37            Action
# 1        Shubh Mangal Zyada Saavdhan             62.78            Comedy
# 2                             Malang             58.04           Romance
# 3                   Street Dancer 3D             74.22             Dance
# 4        Tanhaji: The Unsung Warrior            276.90  Historical Drama
# 5                         Good Newwz            201.14            Comedy
# 6                          Dabangg 3            145.90            Action
# 7                 Pati Patni Aur Woh             86.77            Comedy
# 8                               Bala            115.28            Comedy
# 9                        Housefull 4            194.59            Comedy
# 10                               War            318.01            Action
# 11                        Dream Girl            139.70            Comedy
# 12                        Chhichhore            150.36            Comedy
# 13                             Saaho            130.98            Action
# 14                       Batla House             86.04            Action
# 15                    Mission Mangal            200.16            Sci-fi
# 16                          Super 30            146.58      Biographical
# 17                        Article 15             63.05               NaN
# 18                       Kabir Singh            278.24           Romance
# 19                            Bharat            201.86            Action
# 20                    De De Pyaar De             95.86            Comedy
# 21             Student Of The Year 2             68.82            Action
# 22                            Kalank             74.23           Romance
# 23                            Kesari            150.91  Historical Drama
# 24                             Badla             88.02               NaN
# 25                       Luka Chuppi             94.15            Comedy
# 26                     Total Dhamaal            150.76            Comedy
# 27                         Gully Boy            139.38           Musical
# 28  Manikarnika: The Queen Of Jhansi             91.70      Biographical
# 29          Uri: The Surgical Strike            244.06            Action
# 30                            Simmba            240.22            Action
# 31                              Zero             88.85            Comedy
# 32                         Kedarnath             57.44           Romance
# 33                               two            177.75            Sci-fi
# 34                Thugs Of Hindostan            151.04            Action
# 35                        Badhaai Ho            136.80            Comedy
# 36         Sui Dhaaga: Made In India             79.02               NaN
# 37                             Stree            129.67            Comedy
# 38                              Gold            107.37               NaN
# 39                  Satyameva Jayate             75.09            Action
# 40                            Dhadak             69.16               NaN
# 41                             Sanju            341.22      Biographical
# 42                            Race 3            161.04            Action
# 43                  Veere Di Wedding             80.23            Comedy
# 44     Parmanu: The Story of Pokhran             65.36            Action
# 45                             Raazi            123.17               NaN
# 46                       102 Not Out             51.79            Comedy
# 47                          Baaghi 2            165.50            Action
# 48                              Raid            101.54               NaN
# 49            Sonu Ke Titu Ki Sweety            108.71            Comedy
# 50                           Pad Man             80.00            Comedy
# 51                         Padmaavat            300.26  Historical Drama
# 52                   Tiger Zinda Hai            339.16            Action
# 53                    Fukrey Returns             80.13            Comedy
# 54                     Golmaal Again            205.52            Comedy
# 55                  Secret Superstar             59.34               NaN
# 56                          Judwaa 2            138.47            Comedy
#
#        Genre3            movie_director                 actor1  \
# 0         NaN                Ahmed Khan          ÊTiger Shroff
# 1     Romance            Hitesh Kewalya      ÊAyushman Khurana
# 2      Action                Mohit Suri      ÊAditya Roy Kapur
# 3         NaN              Remo D'Souza          ÊVarun Dhawan
# 4      Action                   Om Raut            ÊAjay Devgn
# 5         NaN                 Raj Mehta          ÊAkshay Kumar
# 6         NaN               Prabhu Deva           ÊSalman Khan
# 7         NaN             Mudassar Aziz         ÊKartik Aaryan
# 8         NaN              Amar Kaushik      ÊAyushman Khurana
# 9         NaN              Farhad Samji          ÊAkshay Kumar
# 10   Thriller           Siddharth Anand        ÊHrithik Roshan
# 11        NaN          Raaj Shaandilyaa      ÊAyushman Khurana
# 12        NaN             Nitesh Tiwari  ÊSushant Singh Rajput
# 13   Thriller                   Sujeeth               ÊPrabhas
# 14   Thriller             Nikhil Advani          ÊJohn Abraham
# 15        NaN              Jagan Shakti          ÊAkshay Kumar
# 16        NaN                Vikas Bahl        ÊHrithik Roshan
# 17   Thriller             Anubhav Sinha      ÊAyushman Khurana
# 18        NaN       Sandeep Reddy Vanga         ÊShahid Kapoor
# 19     Period           Ali Abbas Zafar           ÊSalman Khan
# 20    Romance                  Akiv Ali            ÊAjay Devgn
# 21    Romance            Punit Malhotra          ÊTiger Shroff
# 22        NaN           Abhishek Varman          ÊVarun Dhawan
# 23     Action              Anurag Singh          ÊAkshay Kumar
# 24   Thriller               Sujoy Ghosh      ÊAmitabh Bachchan
# 25    Romance             Laxman Utekar         ÊKartik Aaryan
# 26        NaN               Indra Kumar            ÊAjay Devgn
# 27        NaN               Zoya Akhtar         ÊRanveer Singh
# 28        NaN                     Krish       ÊJisshu Sengupta
# 29        NaN               Aditya Dhar         ÊVicky Kaushal
# 30     Comedy              Rohit Shetty         ÊRanveer Singh
# 31    Romance              Aanand L Rai        ÊShah Rukh Khan
# 32        NaN           Abhishek Kapoor  ÊSushant Singh Rajput
# 33     Action                   Shankar           ÊRajinikanth
# 34  Adventure     Vijay Krishna Acharya      ÊAmitabh Bachchan
# 35        NaN  Amit Ravindernath Sharma      ÊAyushman Khurana
# 36    Romance           Sharat Katariya          ÊVarun Dhawan
# 37     Horror              Amar Kaushik         ÊRajkummar Rao
# 38        NaN               Reema Kagti          ÊAkshay Kumar
# 39   Thriller              Milap Zaveri          ÊJohn Abraham
# 40    Romance          Shashank Khaitan        ÊIshaan Khatter
# 41        NaN           Rajkumar Hirani         ÊRanbir Kapoor
# 42   Thriller              Remo D'Souza           ÊSalman Khan
# 43        NaN           Shashanka Ghosh        ÊKareena Kapoor
# 44        NaN           Abhishek Sharma          ÊJohn Abraham
# 45   Thriller             Meghna Gulzar            ÊAlia Bhatt
# 46        NaN              Umesh Shukla      ÊAmitabh Bachchan
# 47    Romance                Ahmed Khan          ÊTiger Shroff
# 48   Thriller            Rajkumar Gupta            ÊAjay Devgn
